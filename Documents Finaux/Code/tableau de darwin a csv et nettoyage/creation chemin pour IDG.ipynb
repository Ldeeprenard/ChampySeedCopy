# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("tableau_propre.csv")
df.head()
# Out:
#    Unnamed: 0          id                                       identifier_y  \
# 0           0  2438770494  https://images.ala.org.au/image/proxyImageThum...
# 1           1  2438770494  https://images.ala.org.au/image/proxyImageThum...
# 2           2  2434842541  https://images.ala.org.au/image/proxyImageThum...
# 3           3  2435361192  https://images.ala.org.au/image/proxyImageThum...
# 4           4  2438837736  https://images.ala.org.au/image/proxyImageThum...
#
#   kingdom         phylum           class       order           family  \
# 0   Fungi  Basidiomycota  Agaricomycetes  Agaricales   Hygrophoraceae
# 1   Fungi  Basidiomycota  Agaricomycetes  Agaricales   Hygrophoraceae
# 2   Fungi  Basidiomycota  Agaricomycetes  Agaricales       Mycenaceae
# 3   Fungi  Basidiomycota  Agaricomycetes  Russulales  Bondarzewiaceae
# 4   Fungi  Basidiomycota  Agaricomycetes  Agaricales      Agaricaceae
#
#          genus                 species  verbatimScientificName countryCode  \
# ...

# %% [markdown]
# Création d'un chemin relatif pour chaque image afin que ImageDataGenerator les retrouve

# %%
df["path"] = '/'+df["order"]+'/'+df["family"]+'/'+df["genus"]+'/'+df["species"]+'/'+'im'+df.index.astype('str')+".jpg"

# %%
df.head()
# Out:
#            id                                       identifier_y kingdom  \
# 0  2438770494  https://images.ala.org.au/image/proxyImageThum...   Fungi
# 1  2438770494  https://images.ala.org.au/image/proxyImageThum...   Fungi
# 2  2434842541  https://images.ala.org.au/image/proxyImageThum...   Fungi
# 3  2435361192  https://images.ala.org.au/image/proxyImageThum...   Fungi
# 4  2438837736  https://images.ala.org.au/image/proxyImageThum...   Fungi
#
#           phylum           class       order           family        genus  \
# 0  Basidiomycota  Agaricomycetes  Agaricales   Hygrophoraceae    Hygrocybe
# 1  Basidiomycota  Agaricomycetes  Agaricales   Hygrophoraceae    Hygrocybe
# 2  Basidiomycota  Agaricomycetes  Agaricales       Mycenaceae       Mycena
# 3  Basidiomycota  Agaricomycetes  Russulales  Bondarzewiaceae  Amylosporus
# 4  Basidiomycota  Agaricomycetes  Agaricales      Agaricaceae    Barcheria
#
#                   species  verbatimScientificName countryCode  \
# ...

# %%
df.identifier_y[560752]
# Out:
# 'https://inaturalist-open-data.s3.amazonaws.com/photos/61129780/original.jpeg?1581250173'

# %% [markdown]
# Pour definir le chemin absolu du répertoire de base

# %%
base_dir = 'G:/champiseed'

# %%
df.to_csv('allpath.csv')
